# %%
import pandas as pd

# %%
drivers = pd.DataFrame([
    [1, "Jaya", "Charlotte", 4.8],
    [2, "Manoj", "Atlanta", 4.3],
    [3, "Arjun", None, 4.7],
    [4, "Joe", "Charlotte", 4.9],
    [5, "David", "Houston", 4.2],
    [6, "Lucky", "Atlanta", 4.6],
    [7, "Rose", "New Jersey", 4.1],
    [8, "Sri", "Dallas", 4.5],
    [9, "Sai", "Charlotte", 4.4],
    [10, "Bhanu", "Austin", 4.0]
], columns=["driver_id", "driver_name", "city", "rating"])

# %%
trips = pd.DataFrame([
    [101, 1, 45, "Standard", "2026-06-01"],
    [102, 1, 75, "Premium", "2026-06-12"],
    [103, 2, 30, "Standard", "2026-06-03"],
    [104, 3, 90, "Premium", "2026-06-02"],
    [105, 4, 55, "Standard", "2026-06-04"],
    [106, 4, 85, "Premium", "2026-06-25"],
    [107, 5, 20, "Standard", "2026-06-06"],
    [108, 6, 65, "Premium", "2026-06-27"],
    [109, 7, 35, "Standard", "2026-06-07"],
    [110, 8, 100, "Premium", "2026-06-09"],
    [111, 9, 25, "Standard", "2026-06-10"],
    [112, 10, 40, "Standard", "2026-06-11"],
    [113, 1, 60, "Premium", "2026-06-12"],
    [114, 2, 15, "Standard", "2026-06-13"],
    [115, 3, 70, "Premium", "2026-06-14"],
    [116, 4, 95, "Premium", "2026-06-15"],
    [117, 5, 28, "Standard", "2026-06-16"],
    [118, 6, 48, "Standard", "2026-06-17"],
    [119, 7, 52, "Premium", "2026-06-18"],
    [120, 8, 33, "Standard", "2026-06-19"],
    [121, 9, 88, "Premium", "2026-06-20"],
    [122, 10, 22, "Standard", "2026-06-21"],
    [123, 1, 110, "Premium", "2026-06-22"],
    [124, 3, 42, "Standard", "2026-06-23"],
    [125, 6, 78, "Premium", "2026-06-24"]
], columns=["trip_id", "driver_id", "fare", "trip_type", "trip_date"])

# %%
vehicles = pd.DataFrame([
    [201, 1, "BMW", 2021],
    [202, 2, "Toyota", 2020],
    [203, 3, "Tesla", 2022],
    [204, 4, "Toyota", 2023],
    [205, 5, "Honda", 2019],
    [206, 6, "Tesla", 2021],
    [207, 7, "Audi", 2020],
    [208, 8, "Ferrari", 2022],
    [209, 9, "Honda", 2018],
    [210, 10, "Audi", 2023]
], columns=["vehicle_id", "driver_id", "vehicle_type", "vehicle_year"])

# %%
print(drivers)
# Out:
#    driver_id driver_name        city  rating
# 0          1        Jaya   Charlotte     4.8
# 1          2       Manoj     Atlanta     4.3
# 2          3       Arjun        None     4.7
# 3          4         Joe   Charlotte     4.9
# 4          5       David     Houston     4.2
# 5          6       Lucky     Atlanta     4.6
# 6          7        Rose  New Jersey     4.1
# 7          8         Sri      Dallas     4.5
# 8          9         Sai   Charlotte     4.4
# 9         10       Bhanu      Austin     4.0

# %%
print(drivers[["driver_name", "city"]])
# Out:
#   driver_name        city
# 0        Jaya   Charlotte
# 1       Manoj     Atlanta
# 2       Arjun        None
# 3         Joe   Charlotte
# 4       David     Houston
# 5       Lucky     Atlanta
# 6        Rose  New Jersey
# 7         Sri      Dallas
# 8         Sai   Charlotte
# 9       Bhanu      Austin

# %%
print(trips)
# Out:
#     trip_id  driver_id  fare trip_type   trip_date
# 0       101          1    45  Standard  2026-06-01
# 1       102          1    75   Premium  2026-06-12
# 2       103          2    30  Standard  2026-06-03
# 3       104          3    90   Premium  2026-06-02
# 4       105          4    55  Standard  2026-06-04
# 5       106          4    85   Premium  2026-06-25
# 6       107          5    20  Standard  2026-06-06
# 7       108          6    65   Premium  2026-06-27
# 8       109          7    35  Standard  2026-06-07
# 9       110          8   100   Premium  2026-06-09
# 10      111          9    25  Standard  2026-06-10
# 11      112         10    40  Standard  2026-06-11
# 12      113          1    60   Premium  2026-06-12
# 13      114          2    15  Standard  2026-06-13
# 14      115          3    70   Premium  2026-06-14
# 15      116          4    95   Premium  2026-06-15
# 16      117          5    28  Standard  2026-06-16
# ...

# %%
print(vehicles)
# Out:
#    vehicle_id  driver_id vehicle_type  vehicle_year
# 0         201          1          BMW          2021
# 1         202          2       Toyota          2020
# 2         203          3        Tesla          2022
# 3         204          4       Toyota          2023
# 4         205          5        Honda          2019
# 5         206          6        Tesla          2021
# 6         207          7         Audi          2020
# 7         208          8      Ferrari          2022
# 8         209          9        Honda          2018
# 9         210         10         Audi          2023

# %%
print(drivers["city"].unique())
# Out:
# ['Charlotte' 'Atlanta' None 'Houston' 'New Jersey' 'Dallas' 'Austin']

# %%
print(drivers[drivers["city"] == "Charlotte"])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 3          4         Joe  Charlotte     4.9
# 8          9         Sai  Charlotte     4.4

# %%
print(drivers[drivers["rating"] > 4.5])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 2          3       Arjun       None     4.7
# 3          4         Joe  Charlotte     4.9
# 5          6       Lucky    Atlanta     4.6

# %%
print(trips[trips["fare"] > 50])
# Out:
#     trip_id  driver_id  fare trip_type   trip_date
# 1       102          1    75   Premium  2026-06-12
# 3       104          3    90   Premium  2026-06-02
# 4       105          4    55  Standard  2026-06-04
# 5       106          4    85   Premium  2026-06-25
# 7       108          6    65   Premium  2026-06-27
# 9       110          8   100   Premium  2026-06-09
# 12      113          1    60   Premium  2026-06-12
# 14      115          3    70   Premium  2026-06-14
# 15      116          4    95   Premium  2026-06-15
# 18      119          7    52   Premium  2026-06-18
# 20      121          9    88   Premium  2026-06-20
# 22      123          1   110   Premium  2026-06-22
# 24      125          6    78   Premium  2026-06-24

# %%
print(drivers[drivers["city"].isin(["Charlotte", "Atlanta"])])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 1          2       Manoj    Atlanta     4.3
# 3          4         Joe  Charlotte     4.9
# 5          6       Lucky    Atlanta     4.6
# 8          9         Sai  Charlotte     4.4

# %%
print(drivers[(drivers["city"] == "Charlotte") & (drivers["rating"] > 4.5)])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 3          4         Joe  Charlotte     4.9

# %%
print(drivers[drivers["city"].isin(["Charlotte", "Atlanta", "Dallas"])])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 1          2       Manoj    Atlanta     4.3
# 3          4         Joe  Charlotte     4.9
# 5          6       Lucky    Atlanta     4.6
# 7          8         Sri     Dallas     4.5
# 8          9         Sai  Charlotte     4.4

# %%
print(trips[trips["fare"].between(20, 80)])
# Out:
#     trip_id  driver_id  fare trip_type   trip_date
# 0       101          1    45  Standard  2026-06-01
# 1       102          1    75   Premium  2026-06-12
# 2       103          2    30  Standard  2026-06-03
# 4       105          4    55  Standard  2026-06-04
# 6       107          5    20  Standard  2026-06-06
# 7       108          6    65   Premium  2026-06-27
# 8       109          7    35  Standard  2026-06-07
# 10      111          9    25  Standard  2026-06-10
# 11      112         10    40  Standard  2026-06-11
# 12      113          1    60   Premium  2026-06-12
# 14      115          3    70   Premium  2026-06-14
# 16      117          5    28  Standard  2026-06-16
# 17      118          6    48  Standard  2026-06-17
# 18      119          7    52   Premium  2026-06-18
# 19      120          8    33  Standard  2026-06-19
# 21      122         10    22  Standard  2026-06-21
# 23      124          3    42  Standard  2026-06-23
# ...

# %%
print(drivers[drivers["driver_name"].str.startswith("J")])
# Out:
#    driver_id driver_name       city  rating
# 0          1        Jaya  Charlotte     4.8
# 3          4         Joe  Charlotte     4.9

# %%
print(drivers[drivers["city"].isnull()])
# Out:
#    driver_id driver_name  city  rating
# 2          3       Arjun  None     4.7

# %%
print(drivers.sort_values("rating", ascending=False))
# Out:
#    driver_id driver_name        city  rating
# 3          4         Joe   Charlotte     4.9
# 0          1        Jaya   Charlotte     4.8
# 2          3       Arjun        None     4.7
# 5          6       Lucky     Atlanta     4.6
# 7          8         Sri      Dallas     4.5
# 8          9         Sai   Charlotte     4.4
# 1          2       Manoj     Atlanta     4.3
# 4          5       David     Houston     4.2
# 6          7        Rose  New Jersey     4.1
# 9         10       Bhanu      Austin     4.0

# %%
print(trips.sort_values("fare", ascending=False))
# Out:
#     trip_id  driver_id  fare trip_type   trip_date
# 22      123          1   110   Premium  2026-06-22
# 9       110          8   100   Premium  2026-06-09
# 15      116          4    95   Premium  2026-06-15
# 3       104          3    90   Premium  2026-06-02
# 20      121          9    88   Premium  2026-06-20
# 5       106          4    85   Premium  2026-06-25
# 24      125          6    78   Premium  2026-06-24
# 1       102          1    75   Premium  2026-06-12
# 14      115          3    70   Premium  2026-06-14
# 7       108          6    65   Premium  2026-06-27
# 12      113          1    60   Premium  2026-06-12
# 4       105          4    55  Standard  2026-06-04
# 18      119          7    52   Premium  2026-06-18
# 17      118          6    48  Standard  2026-06-17
# 0       101          1    45  Standard  2026-06-01
# 23      124          3    42  Standard  2026-06-23
# 11      112         10    40  Standard  2026-06-11
# ...

# %%
print(trips.sort_values("fare", ascending=False).head(5))
# Out:
#     trip_id  driver_id  fare trip_type   trip_date
# 22      123          1   110   Premium  2026-06-22
# 9       110          8   100   Premium  2026-06-09
# 15      116          4    95   Premium  2026-06-15
# 3       104          3    90   Premium  2026-06-02
# 20      121          9    88   Premium  2026-06-20

# %%
print(drivers["driver_id"].count())
# Out:
# 10

# %%
print(trips["trip_id"].count())
# Out:
# 25

# %%
print(trips["fare"].sum())
# Out:
# 1406

# %%
print(trips["fare"].mean())
# Out:
# 56.24

# %%
print(trips["fare"].max())
# Out:
# 110

# %%
print(trips["fare"].min())
# Out:
# 15

# %%
print(drivers.groupby("city")["driver_id"].count())
# Out:
# city
# Atlanta       2
# Austin        1
# Charlotte     3
# Dallas        1
# Houston       1
# New Jersey    1
# Name: driver_id, dtype: int64

# %%
print(trips.groupby("trip_type")["trip_id"].count())
# Out:
# trip_type
# Premium     12
# Standard    13
# Name: trip_id, dtype: int64

# %%
print(trips.groupby("driver_id")["fare"].sum())
# Out:
# driver_id
# 1     290
# 2      45
# 3     202
# 4     235
# 5      48
# 6     191
# 7      87
# 8     133
# 9     113
# 10     62
# Name: fare, dtype: int64

# %%
print(trips.groupby("trip_type")["fare"].mean())
# Out:
# trip_type
# Premium     80.666667
# Standard    33.692308
# Name: fare, dtype: float64

# %%
print(trips.groupby("trip_type")["fare"].max())
# Out:
# trip_type
# Premium     110
# Standard     55
# Name: fare, dtype: int64

# %%
print(trips.groupby("trip_type")["fare"].min())
# Out:
# trip_type
# Premium     52
# Standard    15
# Name: fare, dtype: int64

# %%
print(trips.groupby("driver_id")["fare"].sum()[trips.groupby("driver_id")["fare"].sum() > 200])
# Out:
# driver_id
# 1    290
# 3    202
# 4    235
# Name: fare, dtype: int64

# %%
print(trips.groupby("trip_type")["fare"].mean()[trips.groupby("trip_type")["fare"].mean() > 40])
# Out:
# trip_type
# Premium    80.666667
# Name: fare, dtype: float64

# %%
print(pd.merge(drivers, trips, on="driver_id")[["driver_name", "fare"]])
# Out:
#    driver_name  fare
# 0         Jaya    45
# 1         Jaya    75
# 2         Jaya    60
# 3         Jaya   110
# 4        Manoj    30
# 5        Manoj    15
# 6        Arjun    90
# 7        Arjun    70
# 8        Arjun    42
# 9          Joe    55
# 10         Joe    85
# 11         Joe    95
# 12       David    20
# 13       David    28
# 14       Lucky    65
# 15       Lucky    48
# 16       Lucky    78
# 17        Rose    35
# 18        Rose    52
# 19         Sri   100
# 20         Sri    33
# 21         Sai    25
# 22         Sai    88
# 23       Bhanu    40
# 24       Bhanu    22

# %%
print(pd.merge(drivers, trips, on="driver_id")[["driver_name", "trip_type"]])
# Out:
#    driver_name trip_type
# 0         Jaya  Standard
# 1         Jaya   Premium
# 2         Jaya   Premium
# 3         Jaya   Premium
# 4        Manoj  Standard
# 5        Manoj  Standard
# 6        Arjun   Premium
# 7        Arjun   Premium
# 8        Arjun  Standard
# 9          Joe  Standard
# 10         Joe   Premium
# 11         Joe   Premium
# 12       David  Standard
# 13       David  Standard
# 14       Lucky   Premium
# 15       Lucky  Standard
# 16       Lucky   Premium
# 17        Rose  Standard
# 18        Rose   Premium
# 19         Sri   Premium
# 20         Sri  Standard
# 21         Sai  Standard
# 22         Sai   Premium
# 23       Bhanu  Standard
# 24       Bhanu  Standard

# %%
print(pd.merge(drivers, vehicles, on="driver_id")[["driver_name", "vehicle_type"]])
# Out:
#   driver_name vehicle_type
# 0        Jaya          BMW
# 1       Manoj       Toyota
# 2       Arjun        Tesla
# 3         Joe       Toyota
# 4       David        Honda
# 5       Lucky        Tesla
# 6        Rose         Audi
# 7         Sri      Ferrari
# 8         Sai        Honda
# 9       Bhanu         Audi

# %%
print(pd.merge(drivers, vehicles, on="driver_id")[["driver_name", "vehicle_year"]])
# Out:
#   driver_name  vehicle_year
# 0        Jaya          2021
# 1       Manoj          2020
# 2       Arjun          2022
# 3         Joe          2023
# 4       David          2019
# 5       Lucky          2021
# 6        Rose          2020
# 7         Sri          2022
# 8         Sai          2018
# 9       Bhanu          2023

# %%
print(pd.merge(pd.merge(drivers, vehicles, on="driver_id"), trips, on="driver_id")[["driver_name", "vehicle_type", "fare"]])
# Out:
#    driver_name vehicle_type  fare
# 0         Jaya          BMW    45
# 1         Jaya          BMW    75
# 2         Jaya          BMW    60
# 3         Jaya          BMW   110
# 4        Manoj       Toyota    30
# 5        Manoj       Toyota    15
# 6        Arjun        Tesla    90
# 7        Arjun        Tesla    70
# 8        Arjun        Tesla    42
# 9          Joe       Toyota    55
# 10         Joe       Toyota    85
# 11         Joe       Toyota    95
# 12       David        Honda    20
# 13       David        Honda    28
# 14       Lucky        Tesla    65
# 15       Lucky        Tesla    48
# 16       Lucky        Tesla    78
# 17        Rose         Audi    35
# 18        Rose         Audi    52
# 19         Sri      Ferrari   100
# 20         Sri      Ferrari    33
# 21         Sai        Honda    25
# 22         Sai        Honda    88
# 23       Bhanu         Audi    40
# 24       Bhanu         Audi    22

# %%
drivers["rating_bonus"] = drivers["rating"] * 100

# %%
trips["platform_fee"] = trips["fare"] * 0.10

# %%
print(drivers["driver_name"].str.upper())
# Out:
# 0     JAYA
# 1    MANOJ
# 2    ARJUN
# 3      JOE
# 4    DAVID
# 5    LUCKY
# 6     ROSE
# 7      SRI
# 8      SAI
# 9    BHANU
# Name: driver_name, dtype: object

# %%
print(drivers["driver_name"].str.lower())
# Out:
# 0     jaya
# 1    manoj
# 2    arjun
# 3      joe
# 4    david
# 5    lucky
# 6     rose
# 7      sri
# 8      sai
# 9    bhanu
# Name: driver_name, dtype: object

# %%
print(drivers[drivers["driver_name"].str.contains("a", case=False)])
# Out:
#    driver_id driver_name       city  rating  rating_bonus
# 0          1        Jaya  Charlotte     4.8         480.0
# 1          2       Manoj    Atlanta     4.3         430.0
# 2          3       Arjun       None     4.7         470.0
# 4          5       David    Houston     4.2         420.0
# 8          9         Sai  Charlotte     4.4         440.0
# 9         10       Bhanu     Austin     4.0         400.0

# %%
print(drivers.isnull().sum())
# Out:
# driver_id       0
# driver_name     0
# city            1
# rating          0
# rating_bonus    0
# dtype: int64

# %%
drivers["city"] = drivers["city"].fillna("Unknown") 
print(drivers)
# Out:
#    driver_id driver_name        city  rating  rating_bonus
# 0          1        Jaya   Charlotte     4.8         480.0
# 1          2       Manoj     Atlanta     4.3         430.0
# 2          3       Arjun     Unknown     4.7         470.0
# 3          4         Joe   Charlotte     4.9         490.0
# 4          5       David     Houston     4.2         420.0
# 5          6       Lucky     Atlanta     4.6         460.0
# 6          7        Rose  New Jersey     4.1         410.0
# 7          8         Sri      Dallas     4.5         450.0
# 8          9         Sai   Charlotte     4.4         440.0
# 9         10       Bhanu      Austin     4.0         400.0

# %%
print(drivers.dropna())
# Out:
#    driver_id driver_name        city  rating  rating_bonus
# 0          1        Jaya   Charlotte     4.8         480.0
# 1          2       Manoj     Atlanta     4.3         430.0
# 2          3       Arjun     Unknown     4.7         470.0
# 3          4         Joe   Charlotte     4.9         490.0
# 4          5       David     Houston     4.2         420.0
# 5          6       Lucky     Atlanta     4.6         460.0
# 6          7        Rose  New Jersey     4.1         410.0
# 7          8         Sri      Dallas     4.5         450.0
# 8          9         Sai   Charlotte     4.4         440.0
# 9         10       Bhanu      Austin     4.0         400.0

# %%
drivers = drivers.rename(columns={"driver_name": "name"}) 
print(drivers)
# Out:
#    driver_id   name        city  rating  rating_bonus
# 0          1   Jaya   Charlotte     4.8         480.0
# 1          2  Manoj     Atlanta     4.3         430.0
# 2          3  Arjun     Unknown     4.7         470.0
# 3          4    Joe   Charlotte     4.9         490.0
# 4          5  David     Houston     4.2         420.0
# 5          6  Lucky     Atlanta     4.6         460.0
# 6          7   Rose  New Jersey     4.1         410.0
# 7          8    Sri      Dallas     4.5         450.0
# 8          9    Sai   Charlotte     4.4         440.0
# 9         10  Bhanu      Austin     4.0         400.0

# %%
print(drivers.sample(5))
# Out:
#    driver_id   name       city  rating  rating_bonus
# 0          1   Jaya  Charlotte     4.8         480.0
# 4          5  David    Houston     4.2         420.0
# 9         10  Bhanu     Austin     4.0         400.0
# 7          8    Sri     Dallas     4.5         450.0
# 5          6  Lucky    Atlanta     4.6         460.0
